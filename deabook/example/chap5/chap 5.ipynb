# %%
# import packages
from deabook import DEAweak
from deabook.constant import CET_ADDI, RTS_VRS1,RTS_VRS2, RTS_CRS, OPT_LOCAL
                        

import pandas as pd
# import all data (including the contextual varibale)

kind = "country" # "province" or "country"

if kind == "province":
    dmuname = '省份'
    data = pd.read_excel(r"../../data\china data.xlsx").query('year>2015').reset_index(drop=True)
    region = data[["省份","group"]]
else:
    dmuname = '国家'
    data = pd.read_excel(r"../../data\oecd data.xlsx").query('year>2015').reset_index(drop=True)


yearid = data[['year',dmuname]]
yearid
# Out:
#      year    国家
# 0    2016  澳大利亚
# 1    2017  澳大利亚
# 2    2018  澳大利亚
# 3    2019  澳大利亚
# 4    2016   奥地利
# ..    ...   ...
# 127  2019   土耳其
# 128  2016    美国
# 129  2017    美国
# 130  2018    美国
# 131  2019    美国
#
# [132 rows x 2 columns]

# %%
data
# Out:
#      year    国家             K             Y           L           E  \
# 0    2016  澳大利亚  5.956383e+09  1.342079e+09   12.071554    6.009312
# 1    2017  澳大利亚  6.090384e+09  1.381660e+09   12.324088    6.200201
# 2    2018  澳大利亚  6.214957e+09  1.411518e+09   12.619437    6.161212
# 3    2019  澳大利亚  6.325938e+09  1.407497e+09   12.863174    6.123273
# 4    2016   奥地利  2.642944e+09  4.272328e+08    4.321229    1.461469
# ..    ...   ...           ...           ...         ...         ...
# 127  2019   土耳其  1.141520e+10  2.506658e+09   28.087334    6.609000
# 128  2016    美国  6.408426e+10  1.855046e+10  152.396957   97.383603
# 129  2017    美国  6.502516e+10  1.898318e+10  154.672318   97.659855
# 130  2018    美国  6.605931e+10  1.955201e+10  156.675903  101.234876
# 131  2019    美国  6.708090e+10  1.997456e+10  158.299591  100.470646
#
#           coal        gas  petroleum  nuclear_renewable        CO2
# 0     1.851000   1.561519   2.269023           0.327769   415.9452
# 1     1.834908   1.632484   2.370096           0.362713   414.7512
# 2     1.763525   1.586028   2.416194           0.395464   416.0012
# 3     1.710430   1.555931   2.403160           0.453751   414.5168
# 4     0.085731   0.316651   0.549274           0.509813    67.2155
# ..         ...        ...        ...                ...        ...
# 127   1.791918   1.619161   2.001988           1.195934   399.3449
# 128  14.225905  28.400352  37.194181          18.837677  5248.0239
# 129  13.837465  28.055093  37.522871          19.560595  5207.7513
# 130  13.251532  31.153422  38.354617          19.812072  5375.4906
# 131  11.315595  32.252007  38.329386          19.924565  5255.8162
#
# [132 rows x 11 columns]

# %%
yearid[dmuname].unique()
# Out:
# array(['澳大利亚', '奥地利', '比利时', '加拿大', '瑞士', '智利', '捷克', '德国', '丹麦', '西班牙',
#        '爱沙尼亚', '芬兰', '法国', '英国', '希腊', '匈牙利', '爱尔兰', '以色列', '意大利', '日本',
#        '韩国', '卢森', '墨西哥', '荷兰', '挪威', '新西兰', '波兰', '葡萄牙', '斯洛伐克', '斯洛文尼亚',
#        '瑞典', '土耳其', '美国'], dtype=object)

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %% [markdown]
# ## DEA

# %%
# define and solve the test_DEAt model
def DEAweak_CRS():

    model = DEAweak.DEAweak2(data,sent = "K L E=Y:CO2", gy=[0],gx=[0,0,0],gb=[1], rts=RTS_CRS, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res
DEAweak_CRS = DEAweak_CRS()
DEAweak_CRS
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  0.221276  0.221276
# 1                    ok  0.231053  0.231053
# 2                    ok  0.235773  0.235773
# 3                    ok  0.227925  0.227925
# 4                    ok  0.348680  0.348680
# ..                  ...       ...       ...
# 127                  ok  0.411694  0.411694
# 128                  ok  0.462620  0.462620
# 129                  ok  0.494134  0.494134
# 130                  ok  0.520340  0.520340
# 131                  ok  0.556082  0.556082
#
# [132 rows x 3 columns]

# %%
def DEAweak_VRS1():


    model = DEAweak.DEAweak2(data,sent = "K L E=Y:CO2", gy=[0],gx=[0,0,0],gb=[1], rts=RTS_VRS1, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DEAweak_VRS1 = DEAweak_VRS1()
DEAweak_VRS1
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  0.421152  0.421152
# 1                    ok  0.447698  0.447698
# 2                    ok  0.460675  0.460675
# 3                    ok  0.435135  0.435135
# 4                    ok  0.365419  0.365419
# ..                  ...       ...       ...
# 127                  ok  0.895441  0.895441
# 128                  ok  0.921229  0.921229
# 129                  ok  0.952928  0.952928
# 130                  ok  0.954488  0.954488
# 131                  ok  1.000000  1.000000
#
# [132 rows x 3 columns]

# %%
def DEAweak_VRS2():


    model = DEAweak.DEAweak2(data,sent = "K L E=Y:CO2", gy=[0],gx=[0,0,0],gb=[1], rts=RTS_VRS2, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res


DEAweak_VRS2 = DEAweak_VRS2()
DEAweak_VRS2
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  0.421152  0.421152
# 1                    ok  0.447698  0.447698
# 2                    ok  0.460675  0.460675
# 3                    ok  0.435135  0.435135
# 4                    ok  0.348680  0.348680
# ..                  ...       ...       ...
# 127                  ok  0.895441  0.895441
# 128                  ok  0.921229  0.921229
# 129                  ok  0.952928  0.952928
# 130                  ok  0.954488  0.954488
# 131                  ok  1.000000  1.000000
#
# [132 rows x 3 columns]

# %%
DEAweak_CRS = DEAweak_CRS.drop(columns = ['optimization_status','rho'])

DEAweak_VRS1 = DEAweak_VRS1.drop(columns = ['optimization_status','rho'])
DEAweak_VRS2 = DEAweak_VRS2.drop(columns = ['optimization_status','rho'])


DEAweak_CRS =  DEAweak_CRS.rename(columns={'te':'PEE_CRS'})
DEAweak_VRS1 =  DEAweak_VRS1.rename(columns={'te':'PEE_VRS_SAME', })
DEAweak_VRS2 =  DEAweak_VRS2.rename(columns={'te':'PEE_VRS_DIFF'})

DEAweak_CRS2 = pd.concat([DEAweak_CRS,yearid],axis=1)
DEAweak_VRS12 = pd.concat([DEAweak_VRS1,yearid],axis=1)
DEAweak_VRS22 = pd.concat([DEAweak_VRS2,yearid],axis=1)

# %%
DEAweak_CRS2.query('year==2017').sort_values('PEE_CRS')
# Out:
#       PEE_CRS  year     国家
# 41   0.110733  2017   爱沙尼亚
# 81   0.167486  2017     韩国
# 25   0.178995  2017     捷克
# 13   0.193474  2017    加拿大
# 57   0.202023  2017     希腊
# 113  0.214119  2017   斯洛伐克
# 77   0.215272  2017     日本
# 1    0.231053  2017   澳大利亚
# 117  0.236662  2017  斯洛文尼亚
# 9    0.269146  2017    比利时
# 61   0.270713  2017    匈牙利
# 45   0.288832  2017     芬兰
# 21   0.291396  2017     智利
# 109  0.295783  2017    葡萄牙
# 93   0.300684  2017     荷兰
# 29   0.301215  2017     德国
# 85   0.308842  2017     卢森
# 5    0.344819  2017    奥地利
# 37   0.350532  2017    西班牙
# 73   0.365191  2017    意大利
# 89   0.366684  2017    墨西哥
# 125  0.410245  2017    土耳其
# 33   0.452457  2017     丹麦
# 49   0.454061  2017     法国
# 53   0.476481  2017     英国
# 129  0.494134  2017     美国
# 97   0.566448  2017     挪威
# 69   0.567668  2017    以色列
# 121  0.648773  2017     瑞典
# 101  0.722559  2017    新西兰
# 105  0.817494  2017     波兰
# 65   0.873251  2017    爱尔兰
# 17   0.924123  2017     瑞士

# %%
DEAweak_VRS12.query('year==2017').sort_values('PEE_VRS_SAME')
# Out:
#      PEE_VRS_SAME  year     国家
# 25       0.196882  2017     捷克
# 57       0.213001  2017     希腊
# 9        0.271694  2017    比利时
# 81       0.303309  2017     韩国
# 109      0.307688  2017    葡萄牙
# 21       0.318654  2017     智利
# 61       0.352529  2017    匈牙利
# 113      0.354191  2017   斯洛伐克
# 5        0.360399  2017    奥地利
# 13       0.380040  2017    加拿大
# 45       0.383040  2017     芬兰
# 93       0.388677  2017     荷兰
# 1        0.447698  2017   澳大利亚
# 117      0.503899  2017  斯洛文尼亚
# 33       0.554617  2017     丹麦
# 37       0.605741  2017    西班牙
# 77       0.612032  2017     日本
# 97       0.615650  2017     挪威
# 69       0.651748  2017    以色列
# 73       0.672574  2017    意大利
# 121      0.680786  2017     瑞典
# 29       0.693106  2017     德国
# 89       0.806192  2017    墨西哥
# 105      0.821973  2017     波兰
# 49       0.860314  2017     法国
# 65       0.893656  2017    爱尔兰
# 17       0.929407  2017     瑞士
# 53       0.943300  2017     英国
# 129      0.952928  2017     美国
# 85       0.982146  2017     卢森
# 101      0.988201  2017    新西兰
# 41       1.000000  2017   爱沙尼亚
# 125      1.000000  2017    土耳其

# %%
DEAweak_CRS3 = DEAweak_CRS2.pivot_table(
    values=['PEE_CRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DEAweak_VRS13 = DEAweak_VRS12.pivot_table(
    values=[  	'PEE_VRS_SAME'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DEAweak_VRS23 = DEAweak_VRS22.pivot_table(
    values=['PEE_VRS_DIFF'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
# 瑞士        0.892558  0.929407  0.993960  1.000000
# 美国        0.921229  0.952928  0.954488  1.000000
# 芬兰        0.353135  0.383040  0.375913  0.406996
# 英国        0.893988  0.943300  0.961097  1.000000
# 荷兰        0.364961  0.388677  0.431983  0.465062
# 葡萄牙       0.325627  0.307688  0.339074  0.374293
# 西班牙       0.614779  0.605741  0.635696  0.698386
# 韩国        0.305703  0.303309  0.303224  0.320750

# %%
DEAweak_VRS23
# Out:
#       PEE_VRS_DIFF
# year          2016      2017      2018      2019
# 国家
# 丹麦        0.423497  0.474193  0.489124  0.575013
# 以色列       0.613556  0.651748  0.641634  0.640547
# 加拿大       0.362313  0.380040  0.388093  0.393022
# 匈牙利       0.294360  0.302649  0.330755  0.352654
# 卢森        1.000000  0.978174  0.963828  0.950979
# 土耳其       0.905071  1.000000  1.000000  0.895441
# 墨西哥       0.744228  0.806192  0.842491  0.842928
# 奥地利       0.348680  0.344819  0.369836  0.367373
# 希腊        0.209200  0.202023  0.213880  0.237973
# 德国        0.642395  0.693106  0.742425  0.796429
# 意大利       0.649931  0.672574  0.687543  0.709114
# 挪威        0.580680  0.597859  0.594383  0.610480
# 捷克        0.171678  0.178995  0.187267  0.201753
# 斯洛伐克      0.284583  0.287003  0.303661  0.331355
# 斯洛文尼亚     0.248364  0.264832  0.290026  0.318665
# 新西兰       0.972531  0.988201  1.000000  0.957284
# 日本        0.579790  0.612032  0.639836  0.669957
# 智利        0.314222  0.308798  0.320118  0.304758
# 比利时       0.263762  0.269146  0.271893  0.277970
# 法国        0.846752  0.860314  0.917870  0.952779
# 波兰        0.794619  0.821973  0.892019  1.000000
# 澳大利亚      0.421152  0.447698  0.460675  0.435135
# 爱尔兰       0.785921  0.891372  1.000000  1.000000
# 爱沙尼亚      1.000000  1.000000  1.000000  1.000000
# 瑞典        0.622759  0.648773  0.669254  0.696871
# 瑞士        0.886263  0.924123  0.993252  1.000000
# 美国        0.921229  0.952928  0.954488  1.000000
# 芬兰        0.299802  0.333091  0.325289  0.349138
# 英国        0.893988  0.943300  0.961097  1.000000
# 荷兰        0.364961  0.388677  0.431983  0.465062
# 葡萄牙       0.312791  0.295783  0.326296  0.360650
# 西班牙       0.614779  0.605741  0.635696  0.698386
# 韩国        0.305703  0.303309  0.303224  0.320750

# %%
DEAweak_CRS3.to_markdown("table5.2_DEA_UO_CRS.md")
DEAweak_VRS13.to_markdown("table5.3_DEA_UO_VRS_SAME.md")
DEAweak_VRS23.to_markdown("table5.4_DEA_UO_VRS_DIFF.md")

# %%
SSS

# %% [markdown]
# ## HYPER

# %%
from deabook import DEAweak
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_VRS2,RTS_CRS,OPT_LOCAL

# %%
def HYPER_CRS():

    model = DEAweak.DEAweak2(data,sent = "K L E=Y:CO2", gy=[1],gx=[0,0,0],gb=[1], rts=RTS_CRS, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

HYPER_CRS = HYPER_CRS()
HYPER_CRS
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  0.221276  0.470399
# 1                    ok  0.231053  0.480679
# 2                    ok  0.235773  0.485565
# 3                    ok  0.227925  0.477415
# 4                    ok  0.348680  0.590491
# ..                  ...       ...       ...
# 127                  ok  0.411694  0.641634
# 128                  ok  0.462620  0.680161
# 129                  ok  0.494134  0.702947
# 130                  ok  0.520340  0.721346
# 131                  ok  0.556082  0.745709
#
# [132 rows x 3 columns]

# %%
def HYPER_VRS1():

    model = DEAweak.DEAweak2(data,sent = "K L E=Y:CO2", gy=[1],gx=[0,0,0],gb=[1], rts=RTS_VRS1, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

HYPER_VRS1=HYPER_VRS1()
HYPER_VRS1
# Out:
# Optimizing locally.
#     optimization_status           rho      teuo       teo
# 0                    ok  1.403403e-16  1.000000  1.000000
# 1                    ok  8.767318e-02  0.912327  0.919394
# 2                    ok  1.052671e-02  0.989473  0.989583
# 3                    ok  6.237507e-02  0.937625  0.941287
# 4                    ok  3.731256e-01  0.626874  0.728265
# ..                  ...           ...       ...       ...
# 127                  ok  1.307620e-02  0.986924  0.987093
# 128                  ok  2.654742e-02  0.973453  0.974139
# 129                  ok  2.027277e-02  0.979727  0.980130
# 130                  ok  0.000000e+00  1.000000  1.000000
# 131                  ok  0.000000e+00  1.000000  1.000000
#
# [132 rows x 4 columns]

# %%
def HYPER_VRS2():

    model = DEAweak.DEAweak2(data,sent = "K L E=Y:CO2", gy=[1],gx=[0,0,0],gb=[1], rts=RTS_VRS2, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

HYPER_VRS2=HYPER_VRS2()
HYPER_VRS2
# Out:
# Optimizing locally.
#     optimization_status           rho      teuo       teo
# 0                    ok  3.460577e-16  1.000000  1.000000
# 1                    ok  8.767318e-02  0.912327  0.919394
# 2                    ok  1.052671e-02  0.989473  0.989583
# 3                    ok  6.237507e-02  0.937625  0.941287
# 4                    ok  3.731256e-01  0.626874  0.728265
# ..                  ...           ...       ...       ...
# 127                  ok  1.307620e-02  0.986924  0.987093
# 128                  ok  2.654742e-02  0.973453  0.974139
# 129                  ok  2.027277e-02  0.979727  0.980130
# 130                  ok  0.000000e+00  1.000000  1.000000
# 131                  ok -9.996808e-18  1.000000  1.000000
#
# [132 rows x 4 columns]

# %%
HYPER_CRS = HYPER_CRS.drop(columns = ['optimization_status','rho'])

HYPER_VRS1 = HYPER_VRS1.drop(columns = ['optimization_status','rho'])
HYPER_VRS2 = HYPER_VRS2.drop(columns = ['optimization_status','rho'])


HYPER_CRS =  HYPER_CRS.rename(columns={'te':'MEE_CRS'})
HYPER_VRS1 =  HYPER_VRS1.rename(columns={'teuo':'MEE_BO_VRS_SAME', })
HYPER_VRS1 =  HYPER_VRS1.rename(columns={'teo':'MEE_O_VRS_SAME', })
HYPER_VRS2 =  HYPER_VRS2.rename(columns={'teuo':'MEE_BO_VRS_DIFF'})
HYPER_VRS2 =  HYPER_VRS2.rename(columns={'teo':'MEE_O_VRS_DIFF'})

HYPER_CRS = pd.concat([HYPER_CRS,yearid],axis=1)
HYPER_VRS1 = pd.concat([HYPER_VRS1,yearid],axis=1)
HYPER_VRS2 = pd.concat([HYPER_VRS2,yearid],axis=1)

# %%
HYPER_CRS
# Out:
#       MEE_CRS  year    国家
# 0    0.470399  2016  澳大利亚
# 1    0.480679  2017  澳大利亚
# 2    0.485565  2018  澳大利亚
# 3    0.477415  2019  澳大利亚
# 4    0.590491  2016   奥地利
# ..        ...   ...   ...
# 127  0.641634  2019   土耳其
# 128  0.680161  2016    美国
# 129  0.702947  2017    美国
# 130  0.721346  2018    美国
# 131  0.745709  2019    美国
#
# [132 rows x 3 columns]

# %%
HYPER_VRS1
# Out:
#      MEE_UO_VRS_SAME  MEE_O_VRS_SAME  year    国家
# 0           1.000000        1.000000  2016  澳大利亚
# 1           0.912327        0.919394  2017  澳大利亚
# 2           0.989473        0.989583  2018  澳大利亚
# 3           0.937625        0.941287  2019  澳大利亚
# 4           0.626874        0.728265  2016   奥地利
# ..               ...             ...   ...   ...
# 127         0.986924        0.987093  2019   土耳其
# 128         0.973453        0.974139  2016    美国
# 129         0.979727        0.980130  2017    美国
# 130         1.000000        1.000000  2018    美国
# 131         1.000000        1.000000  2019    美国
#
# [132 rows x 4 columns]

# %%
HYPER_VRS2
# Out:
#      MEE_UO_VRS_DIFF  MEE_O_VRS_DIFF  year    国家
# 0           1.000000        1.000000  2016  澳大利亚
# 1           0.912327        0.919394  2017  澳大利亚
# 2           0.989473        0.989583  2018  澳大利亚
# 3           0.937625        0.941287  2019  澳大利亚
# 4           0.626874        0.728265  2016   奥地利
# ..               ...             ...   ...   ...
# 127         0.986924        0.987093  2019   土耳其
# 128         0.973453        0.974139  2016    美国
# 129         0.979727        0.980130  2017    美国
# 130         1.000000        1.000000  2018    美国
# 131         1.000000        1.000000  2019    美国
#
# [132 rows x 4 columns]

# %%
HYPER_CRS3 = HYPER_CRS.pivot_table(
    values=['MEE_CRS'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
HYPER_VRS13 = HYPER_VRS1.pivot_table(
    values=['MEE_BO_VRS_SAME', 'MEE_O_VRS_SAME'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
HYPER_VRS23 = HYPER_VRS2.pivot_table(
    values=['MEE_BO_VRS_DIFF', 'MEE_O_VRS_DIFF'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
HYPER_CRS3.to_markdown("table5.5_HYPER_CRS.md")
HYPER_VRS13.to_markdown("table5.6_HYPER_VRS1.md")
HYPER_VRS23.to_markdown("table5.7_HYPER_VRS2.md")

# %%
ssss

# %% [markdown]
# ## DDF

# %%
from deabook import DEAweak
from deabook.constant import CET_ADDI, RTS_VRS1,RTS_VRS2, RTS_CRS, OPT_DEFAULT, OPT_LOCAL

# %%
def DDF_CRS():

    model = DEAweak.DDFweak2(data,sent = "K L E=Y:CO2",  gy=[1], gx=[0,0,0],gb=[1],rts=RTS_CRS,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_CRS=DDF_CRS()
DDF_CRS
# Out:
# Optimizing locally.
#     optimization_status           rho  objective_value      teuo       teo
# 0                    ok  2.821781e-01     2.821781e-01  0.717822  0.779923
# 1                    ok  2.731792e-01     2.731792e-01  0.726821  0.785435
# 2                    ok  2.728685e-01     2.728685e-01  0.727132  0.785627
# 3                    ok  3.003410e-01     3.003410e-01  0.699659  0.769029
# 4                    ok  3.931928e-01     3.931928e-01  0.606807  0.717776
# ..                  ...           ...              ...       ...       ...
# 127                  ok  2.425321e-01     2.425321e-01  0.757468  0.804808
# 128                  ok  2.775482e-02     2.775482e-02  0.972245  0.972995
# 129                  ok  2.197284e-02     2.197284e-02  0.978027  0.978500
# 130                  ok -1.291803e-17    -1.291803e-17  1.000000  1.000000
# 131                  ok  0.000000e+00     0.000000e+00  1.000000  1.000000
#
# [132 rows x 5 columns]

# %%
def DDF_VRS_SAME():

    model = DEAweak.DDFweak2(data,sent = "K L E=Y:CO2",  gy=[1], gx=[0,0,0],gb=[1],rts=RTS_VRS1,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_VRS_SAME=DDF_VRS_SAME()
DDF_VRS_SAME
# Out:
# Optimizing locally.
#     optimization_status           rho  objective_value      teuo       teo
# 0                    ok  1.403403e-16     1.403403e-16  1.000000  1.000000
# 1                    ok  8.767318e-02     8.767318e-02  0.912327  0.919394
# 2                    ok  1.052671e-02     1.052671e-02  0.989473  0.989583
# 3                    ok  6.237507e-02     6.237507e-02  0.937625  0.941287
# 4                    ok  3.731256e-01     3.731256e-01  0.626874  0.728265
# ..                  ...           ...              ...       ...       ...
# 127                  ok  1.307620e-02     1.307620e-02  0.986924  0.987093
# 128                  ok  2.654742e-02     2.654742e-02  0.973453  0.974139
# 129                  ok  2.027277e-02     2.027277e-02  0.979727  0.980130
# 130                  ok  0.000000e+00     0.000000e+00  1.000000  1.000000
# 131                  ok  0.000000e+00     0.000000e+00  1.000000  1.000000
#
# [132 rows x 5 columns]

# %%
def DDF_VRS_DIFF():

    model = DEAweak.DDFweak2(data,sent = "K L E=Y:CO2",  gy=[1], gx=[0,0,0],gb=[1],rts=RTS_VRS2, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_VRS_DIFF = DDF_VRS_DIFF()
DDF_VRS_DIFF
# Out:
# Optimizing locally.
#     optimization_status           rho  objective_value      teuo       teo
# 0                    ok  3.460577e-16     3.460577e-16  1.000000  1.000000
# 1                    ok  8.767318e-02     8.767318e-02  0.912327  0.919394
# 2                    ok  1.052671e-02     1.052671e-02  0.989473  0.989583
# 3                    ok  6.237507e-02     6.237507e-02  0.937625  0.941287
# 4                    ok  3.731256e-01     3.731256e-01  0.626874  0.728265
# ..                  ...           ...              ...       ...       ...
# 127                  ok  1.307620e-02     1.307620e-02  0.986924  0.987093
# 128                  ok  2.654742e-02     2.654742e-02  0.973453  0.974139
# 129                  ok  2.027277e-02     2.027277e-02  0.979727  0.980130
# 130                  ok  0.000000e+00     0.000000e+00  1.000000  1.000000
# 131                  ok -9.996808e-18    -9.996808e-18  1.000000  1.000000
#
# [132 rows x 5 columns]

# %%
DDF_CRS.rename(columns={'teuo':'EB_CRS','teo':'EO_CRS'}, inplace=True)
DDF_VRS_SAME.rename(columns={'teuo':'EB_VRS_SAME','teo':'EO_VRS_SAME'}, inplace=True)
DDF_VRS_DIFF.rename(columns={'teuo':'EB_VRS_DIFF','teo':'EO_VRS_DIFF'}, inplace=True)

DDF_CRS = DDF_CRS.drop(columns = ['optimization_status','rho','objective_value'])
DDF_VRS_SAME = DDF_VRS_SAME.drop(columns = ['optimization_status','rho','objective_value'])
DDF_VRS_DIFF = DDF_VRS_DIFF.drop(columns = ['optimization_status','rho','objective_value'])



DDF_CRS2 = pd.concat([DDF_CRS,yearid],axis=1)
DDF_VRS_SAME2 = pd.concat([DDF_VRS_SAME,yearid],axis=1)
DDF_VRS_DIFF2 = pd.concat([DDF_VRS_DIFF,yearid],axis=1)

# %%
DDF_CRS2
# Out:
#        EB_CRS    EO_CRS  year    国家
# 0    0.717822  0.779923  2016  澳大利亚
# 1    0.726821  0.785435  2017  澳大利亚
# 2    0.727132  0.785627  2018  澳大利亚
# 3    0.699659  0.769029  2019  澳大利亚
# 4    0.606807  0.717776  2016   奥地利
# ..        ...       ...   ...   ...
# 127  0.757468  0.804808  2019   土耳其
# 128  0.972245  0.972995  2016    美国
# 129  0.978027  0.978500  2017    美国
# 130  1.000000  1.000000  2018    美国
# 131  1.000000  1.000000  2019    美国
#
# [132 rows x 4 columns]

# %%
DDF_CRS3 = DDF_CRS2.pivot_table(
    values=['EB_CRS','EO_CRS'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_VRS_SAME3 = DDF_VRS_SAME2.pivot_table(
    values=['EB_VRS_SAME','EO_VRS_SAME'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_VRS_DIFF3 = DDF_VRS_DIFF2.pivot_table(
    values=['EB_VRS_DIFF',  'EO_VRS_DIFF'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_CRS3.to_markdown("table5.8_DDF_CRS.md")
DDF_VRS_SAME3.to_markdown("table5.9_DDF_VRS_SAME.md")
DDF_VRS_DIFF3.to_markdown("table5.10_DDF_VRS_DIFF.md")

# %%
DDF_CRS3
# Out:
#          EB_CRS                                  EO_CRS                      \
# year       2016      2017      2018      2019      2016      2017      2018
# 国家
# 丹麦     0.725920  0.759692  0.769609  0.818058  0.784880  0.806251  0.812750
# 以色列    0.887506  0.902696  0.902598  0.904205  0.898881  0.911324  0.911244
# 加拿大    0.606297  0.615219  0.618691  0.619608  0.717513  0.722136  0.723951
# 匈牙利    0.603453  0.612705  0.640282  0.661346  0.716052  0.720827  0.735447
# 卢森     0.671221  0.668982  0.673967  0.676163  0.752570  0.751305  0.754129
# 土耳其    0.782898  0.791109  0.774565  0.757468  0.821624  0.827205  0.816037
# 墨西哥    0.735383  0.748721  0.756709  0.749237  0.790753  0.799182  0.804317
# 奥地利    0.606807  0.609029  0.634717  0.632982  0.717776  0.718922  0.732449
# 希腊     0.346014  0.336138  0.352391  0.384455  0.604600  0.601011  0.606940
# 德国     0.658060  0.677398  0.685828  0.688814  0.745190  0.756085  0.760935
# 意大利    0.533651  0.543903  0.549819  0.557078  0.681966  0.686767  0.689569
# 挪威     0.824699  0.834028  0.832061  0.838641  0.850846  0.857653  0.856209
# 捷克     0.397338  0.424741  0.446469  0.472346  0.623962  0.634816  0.643695
# 斯洛伐克   0.553751  0.566571  0.591450  0.609885  0.691444  0.697628  0.709950
# 斯洛文尼亚  0.391173  0.420046  0.449075  0.476453  0.621571  0.632930  0.644777
# 新西兰    0.929029  0.935482  0.942551  0.934785  0.933732  0.939392  0.945672
# 日本     0.558566  0.579955  0.586453  0.595509  0.693754  0.704203  0.707440
# 智利     0.710032  0.696053  0.706012  0.684806  0.775213  0.766903  0.772805
# 比利时    0.503357  0.508814  0.512213  0.518293  0.668162  0.670607  0.672139
# 法国     0.676256  0.685317  0.705077  0.715518  0.755433  0.760640  0.772247
# 波兰     0.956949  1.000000  1.000000  1.000000  0.958726  1.000000  1.000000
# 澳大利亚   0.717822  0.726821  0.727132  0.699659  0.779923  0.785435  0.785627
# 爱尔兰    0.941694  0.965835  1.000000  1.000000  0.944906  0.966964  1.000000
# 爱沙尼亚   0.876846  1.000000  0.936133  0.689259  0.890350  1.000000  0.939967
# 瑞典     0.848433  0.865236  0.876594  0.887891  0.868382  0.881241  0.890150
# 瑞士     0.961489  0.975627  0.998376  1.000000  0.962917  0.976207  0.998379
# 美国     0.972245  0.978027  1.000000  1.000000  0.972995  0.978500  1.000000
# 芬兰     0.604470  0.636044  0.630817  0.651933  0.716573  0.733162  0.730363
# 英国     0.774489  0.789338  0.796328  0.809267  0.815986  0.825995  0.830791
# 荷兰     0.637526  0.658037  0.676379  0.692396  0.733959  0.745177  0.755503
# 葡萄牙    0.476528  0.456531  0.492041  0.530114  0.656395  0.647891  0.663148
# 西班牙    0.596003  0.599128  0.616559  0.644751  0.712252  0.713841  0.722835
# 韩国     0.557913  0.553221  0.550860  0.554700  0.693439  0.691190  0.690064
#
#
# year       2019
# 国家
# 丹麦     0.846065
# 以色列    0.912579
# 加拿大    0.724432
# 匈牙利    0.747019
# 卢森     0.755380
# 土耳其    0.804808
# 墨西哥    0.799512
# 奥地利    0.731519
# 希腊     0.618986
# 德国     0.762668
# 意大利    0.693038
# 挪威     0.861060
# 捷克     0.654599
# 斯洛伐克   0.719365
# 斯洛文尼亚  0.656363
# 新西兰    0.938777
# 日本     0.712002
# 智利     0.760344
# 比利时    0.674897
# 法国     0.778524
# 波兰     1.000000
# 澳大利亚   0.769029
# 爱尔兰    1.000000
# 爱沙尼亚   0.762927
# 瑞典     0.899192
# 瑞士     1.000000
# 美国     1.000000
# 芬兰     0.741803
# 英国     0.839819
# 荷兰     0.764758
# 葡萄牙    0.680325
# 西班牙    0.737872
# 韩国     0.691898

# %%
SSS

# %% [markdown]
# ## NDDF

# %%
from deabook import DEAweak
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_VRS2,RTS_CRS, OPT_DEFAULT, OPT_LOCAL

# %%
def NDDF_CRS():

    model = DEAweak.NDDFweak2(data,sent = "K L E = Y:CO2",  gy=[1], gx=[0,0,0],gb=[1],rts=RTS_CRS, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.get_rhoy())
    return res

NDDF_CRS = NDDF_CRS()
NDDF_CRS
# Out:
# Optimizing locally.
#     optimization_status      rhoY       teY  weight_teY       teo    rhoCO2  \
# 0                    ok  0.197630  0.834982    0.417491  0.417491  0.649955
# 1                    ok  0.189492  0.840695    0.420348  0.420348  0.641049
# 2                    ok  0.188146  0.841647    0.420824  0.420824  0.634808
# 3                    ok  0.212818  0.824526    0.412263  0.412263  0.626955
# 4                    ok  0.244853  0.803308    0.401654  0.401654  0.565945
# ..                  ...       ...       ...         ...       ...       ...
# 127                  ok  0.000000  1.000000    0.500000  0.500000  0.588306
# 128                  ok  0.000000  1.000000    0.500000  0.500000  0.537380
# 129                  ok  0.000000  1.000000    0.500000  0.500000  0.505866
# 130                  ok  0.000000  1.000000    0.500000  0.500000  0.479660
# 131                  ok  0.000000  1.000000    0.500000  0.500000  0.443918
#
#         teCO2  weight_teCO2      teuo    teuo2o  objective_value
# 0    0.350045      0.175023  0.175023  0.419225         0.423792
# 1    0.358951      0.179475  0.179475  0.426969         0.415270
# 2    0.365192      0.182596  0.182596  0.433902         0.411477
# 3    0.373045      0.186522  0.186522  0.452435         0.419887
# 4    0.434055      0.217027  0.217027  0.540334         0.405399
# ..        ...           ...       ...       ...              ...
# 127  0.411694      0.205847  0.205847  0.411694         0.294153
# 128  0.462620      0.231310  0.231310  0.462620         0.268690
# 129  0.494134      0.247067  0.247067  0.494134         0.252933
# 130  0.520340      0.260170  0.260170  0.520340         0.239830
# 131  0.556082      0.278041  0.278041  0.556082         0.221959
#
# [132 rows x 11 columns]

# %%
def NDDF_VRS_SAME():

    model = DEAweak.NDDFweak2(data,sent = "K L E = Y:CO2",  gy=[1], gx=[0,0,0],gb=[1],rts=RTS_VRS1, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.get_rhoy())
    return res

NDDF_VRS_SAME = NDDF_VRS_SAME()
NDDF_VRS_SAME
# Out:
# Optimizing locally.
#     optimization_status      rhoY       teY  weight_teY       teo  \
# 0                    ok  0.000000  1.000000    0.500000  0.500000
# 1                    ok  0.000000  1.000000    0.500000  0.500000
# 2                    ok  0.000000  1.000000    0.500000  0.500000
# 3                    ok  0.000000  1.000000    0.500000  0.500000
# 4                    ok  0.344568  0.743733    0.371867  0.371867
# ..                  ...       ...       ...         ...       ...
# 127                  ok  0.000000  1.000000    0.500000  0.500000
# 128                  ok  0.000000  1.000000    0.500000  0.500000
# 129                  ok  0.000000  1.000000    0.500000  0.500000
# 130                  ok  0.000000  1.000000    0.500000  0.500000
# 131                  ok  0.000000  1.000000    0.500000  0.500000
#
#            rhoCO2     teCO2  weight_teCO2      teuo    teuo2o  objective_value
# 0    5.788476e-01  0.421152      0.210576  0.210576  0.421152     2.894238e-01
# 1    5.523017e-01  0.447698      0.223849  0.223849  0.447698     2.761509e-01
# 2    5.393247e-01  0.460675      0.230338  0.230338  0.460675     2.696624e-01
# 3    5.648651e-01  0.435135      0.217567  0.217567  0.435135     2.824326e-01
# 4    4.498200e-01  0.550180      0.275090  0.275090  0.739754     3.971940e-01
# ..            ...       ...           ...       ...       ...              ...
# 127  1.045593e-01  0.895441      0.447720  0.447720  0.895441     5.227965e-02
# 128  7.877142e-02  0.921229      0.460614  0.460614  0.921229     3.938571e-02
# 129  4.707242e-02  0.952928      0.476464  0.476464  0.952928     2.353621e-02
# 130  4.551152e-02  0.954488      0.477244  0.477244  0.954488     2.275576e-02
# 131 -1.352989e-19  1.000000      0.500000  0.500000  1.000000    -6.764944e-20
#
# [132 rows x 11 columns]

# %%
def NDDF_VRS_DIFF():

    model = DEAweak.NDDFweak2(data,sent = "K L E = Y:CO2",  gy=[1], gx=[0,0,0],gb=[1],rts=RTS_VRS2, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.get_rhoy())
    return res

NDDF_VRS_DIFF = NDDF_VRS_DIFF()
NDDF_VRS_DIFF
# Out:
# Optimizing locally.
#     optimization_status      rhoY       teY  weight_teY       teo  \
# 0                    ok  0.000000  1.000000    0.500000  0.500000
# 1                    ok  0.000000  1.000000    0.500000  0.500000
# 2                    ok  0.000000  1.000000    0.500000  0.500000
# 3                    ok  0.000000  1.000000    0.500000  0.500000
# 4                    ok  0.225412  0.816052    0.408026  0.408026
# ..                  ...       ...       ...         ...       ...
# 127                  ok  0.000000  1.000000    0.500000  0.500000
# 128                  ok  0.000000  1.000000    0.500000  0.500000
# 129                  ok  0.000000  1.000000    0.500000  0.500000
# 130                  ok  0.000000  1.000000    0.500000  0.500000
# 131                  ok  0.000000  1.000000    0.500000  0.500000
#
#            rhoCO2     teCO2  weight_teCO2      teuo    teuo2o  objective_value
# 0    5.788476e-01  0.421152      0.210576  0.210576  0.421152     2.894238e-01
# 1    5.523017e-01  0.447698      0.223849  0.223849  0.447698     2.761509e-01
# 2    5.393247e-01  0.460675      0.230338  0.230338  0.460675     2.696624e-01
# 3    5.648651e-01  0.435135      0.217567  0.217567  0.435135     2.824326e-01
# 4    5.727238e-01  0.427276      0.213638  0.213638  0.523589     3.990679e-01
# ..            ...       ...           ...       ...       ...              ...
# 127  1.045593e-01  0.895441      0.447720  0.447720  0.895441     5.227965e-02
# 128  7.877142e-02  0.921229      0.460614  0.460614  0.921229     3.938571e-02
# 129  4.707242e-02  0.952928      0.476464  0.476464  0.952928     2.353621e-02
# 130  4.551152e-02  0.954488      0.477244  0.477244  0.954488     2.275576e-02
# 131 -1.352989e-19  1.000000      0.500000  0.500000  1.000000    -6.764944e-20
#
# [132 rows x 11 columns]

# %%
NDDF_CRS.rename(columns={'teuo':'EB_CRS','teo':'EO_CRS','teuo2o':'EBO_CRS'}, inplace=True)
NDDF_VRS_SAME.rename(columns={'teuo':'EB_VRS_SAME','teo':'EO_VRS_SAME', 'teuo2o':'EBO_VRS_SAME'}, inplace=True)
NDDF_VRS_DIFF.rename(columns={'teuo':'EB_VRS_DIFF','teo':'EO_VRS_DIFF','teuo2o':'EBO_VRS_DIFF'}, inplace=True)


NDDF_CRS = NDDF_CRS[['EB_CRS','EO_CRS','EBO_CRS']]
NDDF_VRS_SAME = NDDF_VRS_SAME[['EB_VRS_SAME','EO_VRS_SAME','EBO_VRS_SAME']]
NDDF_VRS_DIFF = NDDF_VRS_DIFF[['EB_VRS_DIFF','EO_VRS_DIFF','EBO_VRS_DIFF']]


NDDF_CRS2 = pd.concat([NDDF_CRS,yearid],axis=1)
NDDF_VRS_SAME2 = pd.concat([NDDF_VRS_SAME,yearid],axis=1)
NDDF_VRS_DIFF2 = pd.concat([NDDF_VRS_DIFF,yearid],axis=1)

# %%
NDDF_CRS3 = NDDF_CRS2.pivot_table(
    values=['EB_CRS','EO_CRS','EBO_CRS'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
NDDF_VRS_SAME3 = NDDF_VRS_SAME2.pivot_table(
    values=['EB_VRS_SAME','EO_VRS_SAME','EBO_VRS_SAME'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
NDDF_VRS_DIFF3 = NDDF_VRS_DIFF2.pivot_table(
    values=['EB_VRS_DIFF','EO_VRS_DIFF','EBO_VRS_DIFF'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
NDDF_CRS3
# Out:
#         EBO_CRS                                  EB_CRS                      \
# year       2016      2017      2018      2019      2016      2017      2018
# 国家
# 丹麦     0.470756  0.501511  0.507053  0.570714  0.220486  0.238177  0.242327
# 以色列    0.527876  0.567668  0.565281  0.570995  0.263938  0.283834  0.282641
# 加拿大    0.449018  0.446916  0.447409  0.455258  0.176396  0.177095  0.177760
# 匈牙利    0.737450  0.698134  0.698420  0.301484  0.273447  0.265120  0.272368
# 卢森     0.311122  0.309764  0.315642  0.318536  0.155561  0.154651  0.157821
# 土耳其    0.399915  0.410245  0.409233  0.411694  0.199958  0.205123  0.204617
# 墨西哥    0.541975  0.578109  0.380685  0.385597  0.236995  0.253444  0.190343
# 奥地利    0.540334  0.522188  0.546238  0.542223  0.217027  0.212168  0.224732
# 希腊     2.277721  2.116304  2.138434  1.802200  0.443523  0.420120  0.434527
# 德国     0.622933  0.632737  0.667023  0.334337  0.250169  0.257783  0.271900
# 意大利    1.441715  1.377469  1.351981  1.372376  0.404051  0.396715  0.394556
# 挪威     0.548052  0.566448  0.562798  0.576964  0.274026  0.283224  0.281399
# 捷克     0.859521  0.815564  0.813225  0.848460  0.246814  0.245490  0.250738
# 斯洛伐克   0.724034  0.700629  0.696267  0.600848  0.253384  0.248860  0.252720
# 斯洛文尼亚  1.660573  1.258488  1.227919  1.249748  0.395734  0.332818  0.337019
# 新西兰    0.693661  0.722559  0.747238  0.718454  0.346830  0.361279  0.373619
# 日本     0.685911  0.684675  0.713675  0.590010  0.242673  0.246672  0.257128
# 智利     0.483022  0.511494  0.524038  0.544106  0.210142  0.217976  0.224462
# 比利时    1.092167  1.114226  1.122142  1.146480  0.327317  0.333963  0.336854
# 法国     0.695075  0.688636  0.724682  0.747827  0.279149  0.279590  0.295865
# 波兰     0.785347  0.817494  0.891959  1.000000  0.392674  0.408747  0.445979
# 澳大利亚   0.419225  0.426969  0.433902  0.452435  0.175023  0.179475  0.182596
# 爱尔兰    0.753213  0.873251  1.000000  1.000000  0.376606  0.436625  0.500000
# 爱沙尼亚   0.373253  0.346374  0.364214  0.531916  0.131520  0.125833  0.134877
# 奥地利    0.747218  0.748205
# 希腊     0.612953  0.625925
# 德国     0.935718  0.954757
# 意大利    0.869926  0.870979
# 挪威     0.857383  0.862799
# 捷克     0.665513  0.677901
# 斯洛伐克   0.744879  0.755141
# 斯洛文尼亚  0.763842  0.780449
# 新西兰    1.000000  0.992458
# 日本     0.911983  0.933855
# 智利     0.783319  0.776347
# 比利时    0.711599  0.716252
# 法国     0.961517  0.977902
# 波兰     1.000000  1.000000
# 澳大利亚   0.989583  0.941287
# 爱尔兰    1.000000  1.000000
# 爱沙尼亚   1.000000  1.000000
# 瑞典     0.890237  0.899940
# 瑞士     0.998749  1.000000
# 美国     1.000000  1.000000
# 芬兰     0.741443  0.754411
# 英国     0.993379  1.000000
# 荷兰     0.867846  0.878376
# 葡萄牙    0.669537  0.687147
# 西班牙    0.843011  0.861136
# 韩国     0.788869  0.796833

# %%
hyper_mean_year = HYPER_VRS13['MEE_BO_VRS_SAME'].mean()

# %%
nddf_mean_year = NDDF_VRS_SAME3['EB_VRS_SAME'].mean()
ddf_mean_year = DDF_VRS_SAME3['EB_VRS_SAME'].mean()

xtick2 = tuple(nddf_mean_year.index)

# %%
nddf_mean_year
# Out:
# year
# 2016    0.336500
# 2017    0.343650
# 2018    0.351276
# 2019    0.361706
# dtype: float64

# %%
ddf_mean_year
# Out:
# year
# 2016    0.802210
# 2017    0.812818
# 2018    0.823617
# 2019    0.833011
# dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib notebook
# plt.figure(figsize=(1,1))
params = {
    'figure.figsize': '8, 4'
}
# plt.rcParams.update(params)
# plt.rc('font',family='Times New Roman')
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'


import numpy as np

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################

n_groups = 4 # 样本的数目（ref，mut1-3）
index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.plot(index, hyper_mean_year,
                color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='HYPER_VRS_SAME'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )
rects2 = ax.plot(index, nddf_mean_year,
                color='olivedrab',alpha = 0.8,linestyle = "dashed",marker = "^",label='DDF_VRS_SAME'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )

###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{环境效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# 以色列    0.930167  0.931193
# 加拿大    0.814128  0.816624
# 匈牙利    0.743305  0.754032
# 卢森     0.987891  0.982677
# 土耳其    1.000000  0.987093
# 墨西哥    0.964900  0.963421
# 奥地利    0.747218  0.748205
# 希腊     0.612953  0.625925
# 德国     0.935718  0.954757
# 意大利    0.869926  0.870979
# 挪威     0.857383  0.862799
# 捷克     0.665513  0.677901
# 斯洛伐克   0.744879  0.755141
# 斯洛文尼亚  0.763842  0.780449
# 新西兰    1.000000  0.992458
# 日本     0.911983  0.933855
# 智利     0.783319  0.776347
# 比利时    0.711599  0.716252
# 法国     0.961517  0.977902
# 波兰     1.000000  1.000000
# 澳大利亚   0.989583  0.941287
# 爱尔兰    1.000000  1.000000
# 爱沙尼亚   1.000000  1.000000
# 瑞典     0.890237  0.899940
# 瑞士     0.998749  1.000000
# 美国     1.000000  1.000000
# 芬兰     0.741443  0.754411
# 英国     0.993379  1.000000
# 荷兰     0.867846  0.878376
# 葡萄牙    0.669537  0.687147
# 西班牙    0.843011  0.861136
# 韩国     0.788869  0.796833

# %%
hyper_mean_cou = HYPER_VRS13['MEE_BO_VRS_SAME'].mean(axis=1)
nddf_mean_cou = NDDF_VRS_SAME3['EB_VRS_SAME'].mean(axis=1)

# %%
zz = pd.concat([hyper_mean_cou,nddf_mean_cou],axis=1).sort_values(0)

hyper_mean_cou = zz[0]
nddf_mean_cou = zz[1]
zz
# Out:
#               0         1
# 国家
# 希腊     0.370773  0.261417
# 捷克     0.479131  0.176473
# 葡萄牙    0.503250  0.361793
# 比利时    0.590638  0.184238
# 匈牙利    0.645667  0.286493
# 奥地利    0.647222  0.251702
# 斯洛伐克   0.648937  0.283615
# 芬兰     0.652532  0.306503
# 斯洛文尼亚  0.683692  0.484062
# 智利     0.712712  0.221619
# 韩国     0.735306  0.154401
# 加拿大    0.768349  0.190434
# 丹麦     0.793779  0.298624
# 西班牙    0.812787  0.391879
# 挪威     0.834493  0.307068
# 荷兰     0.836740  0.207836
# 意大利    0.847074  0.396473
# 瑞典     0.869959  0.362487
# 日本     0.908641  0.312702
# 以色列    0.922115  0.318436
# 德国     0.949683  0.359294
# 法国     0.951273  0.462478
# 墨西哥    0.952339  0.404480
# 澳大利亚   0.959856  0.220583
# 爱尔兰    0.978651  0.460462
# 瑞士     0.985833  0.480250
# 美国     0.988295  0.478581
# 波兰     0.989960  0.438576
# 卢森     0.990277  0.490767
# 英国     0.991156  0.474798
# 土耳其    0.993822  0.475064
# 新西兰    0.996225  0.489752
# 爱沙尼亚   1.000000  0.500000

# %%
xtick2 = tuple(nddf_mean_cou.index)
xtick2
# Out:
# ('希腊',
#  '捷克',
#  '葡萄牙',
#  '比利时',
#  '匈牙利',
#  '奥地利',
#  '斯洛伐克',
#  '芬兰',
#  '斯洛文尼亚',
#  '智利',
#  '韩国',
#  '加拿大',
#  '丹麦',
#  '西班牙',
#  '挪威',
#  '荷兰',
#  '意大利',
#  '瑞典',
#  '日本',
#  '以色列',
#  '德国',
#  '法国',
#  '墨西哥',
#  '澳大利亚',
#  '爱尔兰',
#  '瑞士',
#  '美国',
#  '波兰',
#  '卢森',
#  '英国',
#  '土耳其',
#  '新西兰',
#  '爱沙尼亚')

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################
if kind=="province":
   n_groups = 30 # 样本的数目（ref，mut1-3）
else:
   n_groups = 33  

index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.bar(index-bar_width/4, hyper_mean_cou,
                bar_width/2,
                color='darkblue',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='HYPER_VRS_SAME'
              )
rects2 = ax.bar(index+bar_width/4, nddf_mean_cou,
                bar_width/2,
                color='olivedrab',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='NDDF_VRS_SAME'
              )

###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{环境效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend(loc='upper left')#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("分省份环境效率2.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("分国家环境效率2.png", dpi=900, bbox_inches = 'tight')

plt.show()
# Out:
# <div id='d4bacd04-2cec-44af-b1d3-dec3d023a00a'></div>

# %%
if kind=="province":
    HYPER_VRS4 = pd.merge(HYPER_VRS13['MEE_BO_VRS_SAME'].reset_index(),region,on=['省份'],how="left")
    HYPER_VRS5 = HYPER_VRS4.groupby('group').mean()
    NDDF_VRS_SAME4 = pd.merge(NDDF_VRS_SAME3['EB_VRS_SAME'].reset_index(),region,on=['省份'],how="left")
    NDDF_VRS_SAME5 = NDDF_VRS_SAME4.groupby('group').mean()
    xtick2 = tuple(HYPER_VRS5.loc["W"].index)

# %%
if kind=="province":
  fig, ax = plt.subplots() # 创建图形网格


  ax.spines['top'].set_visible(False) # 使上边框不可见
  ax.spines['right'].set_visible(False)
  # ax2.spines['right'].set_visible(False)

  ################################ 绘图 #################################

  n_groups = 4 # 样本的数目（ref，mut1-3）
  index = np.arange(n_groups) # 转换为列表
  bar_width = 0.5 # 设置柱子的宽度
  # opacity = 0.8 # 设置柱子的透明度
  error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



  # 画第一个样本的柱子
  rects1 = ax.plot(index, HYPER_VRS5.loc['E'],
                  color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='东部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  rects2 = ax.plot(index, HYPER_VRS5.loc['C'],
                  color='olivedrab',alpha = 0.8,linestyle = "dashed",marker = "^",label='中部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  rects3 = ax.plot(index, HYPER_VRS5.loc['W'],
                  color='orange',alpha = 0.8,linestyle = "dashed",marker = "+",label='西部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  ###########################################333

  # ax.set_xlabel('Hours in 4 ℃')
  ax.set_ylabel( r'$\mathregular{环境效率}$')
  #  r'$Difficulty of reducing emissions \gamma$' 
  # ax.set_title('Creat by python')
  ax.set_xticks(index )
  ax.set_xticklabels(xtick2)
  # ax2.set_xlabel('Relative gene expression')
  # ax.spines["bottom"].set_position(("data",0))
  plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

  plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
  # ax.legend(frameon=False,loc='best',ncol = 1)
  plt.savefig("分年份地区环境效率-省hyper.png", dpi=900, bbox_inches = 'tight')

  plt.show()

# %%
if kind=="province":
  fig, ax = plt.subplots() # 创建图形网格


  ax.spines['top'].set_visible(False) # 使上边框不可见
  ax.spines['right'].set_visible(False)
  # ax2.spines['right'].set_visible(False)

  ################################ 绘图 #################################

  n_groups = 4 # 样本的数目（ref，mut1-3）
  index = np.arange(n_groups) # 转换为列表
  bar_width = 0.5 # 设置柱子的宽度
  # opacity = 0.8 # 设置柱子的透明度
  error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



  # 画第一个样本的柱子
  rects1 = ax.plot(index, NDDF_VRS_SAME5.loc['E'],
                  color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='东部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  rects2 = ax.plot(index, NDDF_VRS_SAME5.loc['C'],
                  color='olivedrab',alpha = 0.8,linestyle = "dashed",marker = "^",label='中部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  if kind=="province":
      rects3 = ax.plot(index, NDDF_VRS_SAME5.loc['W'],
                      color='orange',alpha = 0.8,linestyle = "dashed",marker = "+",label='西部'
                  #      error_kw=error_config,
                  #   edgecolor = 'white'
                    )
  ###########################################333

  # ax.set_xlabel('Hours in 4 ℃')
  ax.set_ylabel( r'$\mathregular{环境效率}$')
  #  r'$Difficulty of reducing emissions \gamma$' 
  # ax.set_title('Creat by python')
  ax.set_xticks(index )
  ax.set_xticklabels(xtick2)
  # ax2.set_xlabel('Relative gene expression')
  # ax.spines["bottom"].set_position(("data",0))
  plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

  plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
  # ax.legend(frameon=False,loc='best',ncol = 1)
  plt.savefig("分年份地区环境效率-省nddf.png", dpi=900, bbox_inches = 'tight')

  plt.show()
