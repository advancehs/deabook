# %%
# import packages
from deabook import DEA
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_CRS, \
                        OPT_LOCAL

import pandas as pd
# import all data (including the contextual varibale)

kind = "province" # "province" or "country"

if kind == "province":
    dmuname = '省份'
    data = pd.read_excel(r"../../data\china data.xlsx").query('year>2015').reset_index(drop=True)
    region = data[["省份","group"]]
else:
    dmuname = '国家'
    data = pd.read_excel(r"../../data\oecd data.xlsx").query('year>2015').reset_index(drop=True)


yearid = data[['year',dmuname]]
yearid
# Out:
#      year    省份
# 0    2016   上海市
# 1    2017   上海市
# 2    2018   上海市
# 3    2019   上海市
# 4    2016   云南省
# ..    ...   ...
# 115  2019   青海省
# 116  2016  黑龙江省
# 117  2017  黑龙江省
# 118  2018  黑龙江省
# 119  2019  黑龙江省
#
# [120 rows x 2 columns]

# %%
data
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group
# 0       E
# 1       E
# 2       E
# 3       E
# 4       W
# ..    ...
# 115     W
# 116     C
# 117     C
# 118     C
# 119     C
#
# [120 rows x 8 columns]

# %%
yearid[dmuname].unique()
# Out:
# array(['上海市', '云南省', '内蒙古自治区', '北京市', '吉林省', '四川省', '天津市', '宁夏回族自治区',
#        '安徽省', '山东省', '山西省', '广东省', '广西壮族自治区', '新疆维吾尔自治区', '江苏省', '江西省',
#        '河北省', '河南省', '浙江省', '海南省', '湖北省', '湖南省', '甘肃省', '福建省', '贵州省',
#        '辽宁省', '重庆市', '陕西省', '青海省', '黑龙江省'], dtype=object)

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %% [markdown]
# ## DEA

# %%
# define and solve the test_DEAt model
def DEA_CRS():

    model = DEA.DEA2(data,sent = "K L E =Y",   gy=[0], gx=[1,0,0], rts=RTS_CRS,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res
DEA_CRS = DEA_CRS()
DEA_CRS
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  1.000000  1.000000
# 1                    ok  1.000000  1.000000
# 2                    ok  0.820124  0.820124
# 3                    ok  0.726104  0.726104
# 4                    ok  0.404137  0.404137
# ..                  ...       ...       ...
# 115                  ok  0.242119  0.242119
# 116                  ok  0.396372  0.396372
# 117                  ok  0.357861  0.357861
# 118                  ok  0.377166  0.377166
# 119                  ok  0.369581  0.369581
#
# [120 rows x 3 columns]

# %%
def DEA_VRS():

    model = DEA.DEA2(data,sent = "K L E =Y",   gy=[0], gx=[1,0,0], rts=RTS_VRS1,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DEA_VRS = DEA_VRS()
DEA_VRS
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  1.000000  1.000000
# 1                    ok  1.000000  1.000000
# 2                    ok  1.000000  1.000000
# 3                    ok  0.855268  0.855268
# 4                    ok  0.489602  0.489602
# ..                  ...       ...       ...
# 115                  ok  0.928124  0.928124
# 116                  ok  0.493670  0.493670
# 117                  ok  0.449449  0.449449
# 118                  ok  0.473965  0.473965
# 119                  ok  0.462189  0.462189
#
# [120 rows x 3 columns]

# %%
data
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group
# 0       E
# 1       E
# 2       E
# 3       E
# 4       W
# ..    ...
# 115     W
# 116     C
# 117     C
# 118     C
# 119     C
#
# [120 rows x 8 columns]

# %%
DEA_CRS = DEA_CRS.drop(columns = ['optimization_status','rho'])

DEA_VRS = DEA_VRS.drop(columns = ['optimization_status','rho'])


DEA_CRS =  DEA_CRS.rename(columns={'te':'PEO_CRS'})
DEA_VRS =  DEA_VRS.rename(columns={'te':'PEO_VRS'})


DEA_CRS2 = pd.concat([DEA_CRS,yearid],axis=1)
DEA_VRS2 = pd.concat([DEA_VRS,yearid],axis=1)

# %%
DEA_CRS2.query('year==2017').sort_values('PEO_CRS')
# Out:
#       PEO_CRS  year        省份
# 9    0.193460  2017    内蒙古自治区
# 113  0.219538  2017       青海省
# 17   0.257406  2017       吉林省
# 25   0.264958  2017       天津市
# 89   0.267449  2017       甘肃省
# 105  0.268941  2017       重庆市
# 29   0.270371  2017   宁夏回族自治区
# 61   0.277232  2017       江西省
# 97   0.281141  2017       贵州省
# 109  0.285675  2017       陕西省
# 33   0.293054  2017       安徽省
# 49   0.299146  2017   广西壮族自治区
# 69   0.315409  2017       河南省
# 53   0.319632  2017  新疆维吾尔自治区
# 65   0.344169  2017       河北省
# 21   0.350223  2017       四川省
# 5    0.354749  2017       云南省
# 81   0.356777  2017       湖北省
# 117  0.357861  2017      黑龙江省
# 37   0.358531  2017       山东省
# 101  0.358652  2017       辽宁省
# 85   0.362612  2017       湖南省
# 93   0.363619  2017       福建省
# 77   0.376008  2017       海南省
# 41   0.430143  2017       山西省
# 57   0.434095  2017       江苏省
# 73   0.484107  2017       浙江省
# 45   0.722179  2017       广东省
# 13   0.981741  2017       北京市
# 1    1.000000  2017       上海市

# %%
DEA_VRS2.query('year==2017').sort_values('PEO_VRS')
# Out:
#       PEO_VRS  year        省份
# 9    0.274692  2017    内蒙古自治区
# 33   0.314501  2017       安徽省
# 69   0.332420  2017       河南省
# 61   0.333605  2017       江西省
# 109  0.335785  2017       陕西省
# 17   0.341753  2017       吉林省
# 105  0.346966  2017       重庆市
# 49   0.352609  2017   广西壮族自治区
# 65   0.355035  2017       河北省
# 21   0.356937  2017       四川省
# 81   0.365092  2017       湖北省
# 25   0.366903  2017       天津市
# 101  0.377676  2017       辽宁省
# 85   0.378707  2017       湖南省
# 93   0.379849  2017       福建省
# 97   0.402739  2017       贵州省
# 5    0.425438  2017       云南省
# 37   0.440159  2017       山东省
# 117  0.449449  2017      黑龙江省
# 53   0.451226  2017  新疆维吾尔自治区
# 89   0.461604  2017       甘肃省
# 41   0.504958  2017       山西省
# 73   0.564425  2017       浙江省
# 57   0.769586  2017       江苏省
# 113  0.874745  2017       青海省
# 77   0.881673  2017       海南省
# 13   1.000000  2017       北京市
# 29   1.000000  2017   宁夏回族自治区
# 45   1.000000  2017       广东省
# 1    1.000000  2017       上海市

# %%
DEA_CRS3 = DEA_CRS2.pivot_table(
    values=['PEO_CRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DEA_VRS3 = DEA_VRS2.pivot_table(
    values=['PEO_VRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DEA_CRS3
# Out:
#            PEO_CRS
# year          2016      2017      2018      2019
# 省份
# 上海市       1.000000  1.000000  0.820124  0.726104
# 云南省       0.404137  0.354749  0.334123  0.317790
# 内蒙古自治区    0.198095  0.193460  0.111738  0.105349
# 北京市       1.000000  0.981741  1.000000  0.916969
# 吉林省       0.282486  0.257406  0.349254  0.343553
# 四川省       0.372596  0.350223  0.416867  0.409669
# 天津市       0.273397  0.264958  0.296640  0.296118
# 宁夏回族自治区   0.280043  0.270371  0.181783  0.146947
# 安徽省       0.319518  0.293054  0.358800  0.364245
# 山东省       0.398936  0.358531  0.395405  0.393498
# 山西省       0.373447  0.430143  0.407214  0.404799
# 广东省       0.776947  0.722179  0.734421  0.744355
# 广西壮族自治区   0.335895  0.299146  0.323852  0.303373
# 新疆维吾尔自治区  0.338761  0.319632  0.311924  0.226116
# 江苏省       0.465120  0.434095  0.523358  0.508726
# 江西省       0.314067  0.277232  0.308515  0.280820
# 河北省       0.379269  0.344169  0.324816  0.306383
# 河南省       0.348685  0.315409  0.339391  0.343501
# 浙江省       0.520066  0.484107  0.516482  0.500233
# 海南省       0.418890  0.376008  0.194565  0.197586
# 湖北省       0.393626  0.356777  0.407241  0.417371
# 湖南省       0.411573  0.362612  0.395688  0.399299
# 甘肃省       0.270685  0.267449  0.233933  0.228092
# 福建省       0.396961  0.363619  0.427370  0.430920
# 贵州省       0.322995  0.281141  0.278549  0.246627
# 辽宁省       0.336102  0.358652  0.397164  0.403436
# 重庆市       0.300877  0.268941  0.318589  0.320064
# 陕西省       0.312938  0.285675  0.342787  0.325788
# 青海省       0.247162  0.219538  0.239156  0.242119
# 黑龙江省      0.396372  0.357861  0.377166  0.369581

# %%
DEA_CRS3.to_markdown("DEA_CRS.md")
DEA_VRS3.to_markdown("DEA_VRS.md")

# %%
SSS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 SSS
#
# NameError: name 'SSS' is not defined

# %% [markdown]
# ## HYPER

# %%
from deabook import DEA
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_CRS, \
                        OPT_LOCAL

# %%
def HYPER_CRS():

    model = DEA.DEA2(data,sent = "K L E =Y",   gy=[1], gx=[1,0,0], rts=RTS_CRS,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

HYPER_CRS = HYPER_CRS()
HYPER_CRS
# Out:
# Optimizing locally.
#     optimization_status  rho   te
# 0                    ok  0.0  0.0
# 1                    ok  0.0  0.0
# 2                    ok  0.0  0.0
# 3                    ok  0.0  0.0
# 4                    ok  0.0  0.0
# ..                  ...  ...  ...
# 115                  ok  0.0  0.0
# 116                  ok  0.0  0.0
# 117                  ok  0.0  0.0
# 118                  ok  0.0  0.0
# 119                  ok  0.0  0.0
#
# [120 rows x 3 columns]

# %%
def HYPER_VRS():
    model = DEA.DEA2(data,sent = "K L E =Y",   gy=[1], gx=[1,0,0], rts=RTS_VRS1,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

HYPER_VRS=HYPER_VRS()
HYPER_VRS
# Out:
# Optimizing locally.
#     optimization_status       rho       tei       teo
# 0                    ok  1.000000  0.000000  0.500000
# 1                    ok  1.000000  0.000000  0.500000
# 2                    ok  1.000000  0.000000  0.500000
# 3                    ok  0.991568  0.008432  0.502117
# 4                    ok  0.182580  0.817420  0.845608
# ..                  ...       ...       ...       ...
# 115                  ok  0.026614  0.973386  0.974076
# 116                  ok  0.168336  0.831664  0.855918
# 117                  ok  0.164388  0.835612  0.858820
# 118                  ok  0.164125  0.835875  0.859014
# 119                  ok  0.166386  0.833614  0.857349
#
# [120 rows x 4 columns]

# %%
0.166386**2
# Out:
# 0.027684300996000003

# %%
HYPER_CRS = HYPER_CRS.drop(columns = ['optimization_status',])

HYPER_VRS = HYPER_VRS.drop(columns = ['optimization_status',])


HYPER_CRS =  HYPER_CRS.rename(columns={'te':'MEI_CRS', })
HYPER_VRS =  HYPER_VRS.rename(columns={'teo':'MEO_VRS','tei':'MEI_VRS'})

HYPER_CRS2 = pd.concat([HYPER_CRS,yearid],axis=1)
HYPER_VRS2 = pd.concat([HYPER_VRS,yearid],axis=1)

# %%
HYPER_CRS2
# Out:
#           rho   MEI_CRS  year    省份
# 0    1.000000  1.000000  2016   上海市
# 1    1.000000  1.000000  2017   上海市
# 2    0.820124  0.905607  2018   上海市
# 3    0.726104  0.852117  2019   上海市
# 4    0.404137  0.635717  2016   云南省
# ..        ...       ...   ...   ...
# 115  0.242119  0.492056  2019   青海省
# 116  0.396372  0.629581  2016  黑龙江省
# 117  0.357861  0.598214  2017  黑龙江省
# 118  0.377166  0.614138  2018  黑龙江省
# 119  0.369581  0.607932  2019  黑龙江省
#
# [120 rows x 4 columns]

# %%
HYPER_VRS2
# Out:
#           rho   MEI_VRS   MEO_VRS  year    省份
# 0    0.000000  1.000000  1.000000  2016   上海市
# 1    0.000000  1.000000  1.000000  2017   上海市
# 2    0.000000  1.000000  1.000000  2018   上海市
# 3    0.005028  0.994972  0.994997  2019   上海市
# 4    0.384554  0.615446  0.722254  2016   云南省
# ..        ...       ...       ...   ...   ...
# 115  0.027500  0.972500  0.973236  2019   青海省
# 116  0.383305  0.616695  0.722907  2016  黑龙江省
# 117  0.426857  0.573143  0.700841  2017  黑龙江省
# 118  0.402966  0.597034  0.712776  2018  黑龙江省
# 119  0.413934  0.586066  0.707247  2019  黑龙江省
#
# [120 rows x 5 columns]

# %%
HYPER_CRS3 = HYPER_CRS2.pivot_table(
    values=['MEI_CRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
HYPER_VRS3 = HYPER_VRS2.pivot_table(
    values=['MEO_VRS','MEI_VRS'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
HYPER_VRS3
# Out:
#            MEI_VRS                                 MEO_VRS            \
# year          2016      2017      2018      2019      2016      2017
# 省份
# 上海市       1.000000  1.000000  1.000000  0.994972  1.000000  1.000000
# 云南省       0.615446  0.553654  0.524642  0.501580  0.722254  0.691398
# 内蒙古自治区    0.384673  0.372926  0.226652  0.213934  0.619070  0.614600
# 北京市       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 吉林省       0.490879  0.460620  0.587021  0.576777  0.662637  0.649612
# 四川省       0.576277  0.561165  0.633385  0.627468  0.702384  0.695007
# 天津市       0.497548  0.478739  0.519863  0.518645  0.665579  0.657350
# 宁夏回族自治区   0.993769  1.000000  0.996845  1.000000  0.993807  1.000000
# 安徽省       0.490545  0.467961  0.545659  0.552511  0.662491  0.652725
# 山东省       0.755750  0.743200  0.760885  0.770869  0.803697  0.795671
# 山西省       0.582919  0.632841  0.603854  0.600966  0.705676  0.731444
# 广东省       1.000000  1.000000  0.991248  1.000000  1.000000  1.000000
# 广西壮族自治区   0.528086  0.478849  0.507154  0.479640  0.679387  0.657397
# 新疆维吾尔自治区  0.602857  0.564057  0.541860  0.415919  0.715746  0.696406
# 江苏省       0.967242  0.994790  1.000000  0.997890  0.968281  0.994817
# 江西省       0.505061  0.455776  0.493729  0.457068  0.668924  0.647575
# 河北省       0.611534  0.575285  0.553126  0.532529  0.720219  0.701895
# 河南省       0.581919  0.547480  0.578492  0.583821  0.705178  0.688458
# 浙江省       0.880865  0.897504  0.917615  0.910218  0.893548  0.907033
# 海南省       1.000000  0.966792  0.840357  0.799271  1.000000  0.967859
# 湖北省       0.596981  0.565401  0.621485  0.632030  0.712749  0.697059
# 湖南省       0.602088  0.558028  0.589325  0.595876  0.715353  0.693495
# 甘肃省       0.568299  0.557446  0.491602  0.479069  0.698470  0.693215
# 福建省       0.596532  0.576663  0.641905  0.642582  0.712521  0.702574
# 贵州省       0.581576  0.513493  0.504931  0.455651  0.705008  0.672718
# 辽宁省       0.522667  0.548629  0.589671  0.595949  0.676895  0.689004
# 重庆市       0.510195  0.463748  0.530007  0.528608  0.671229  0.650935
# 陕西省       0.499825  0.460568  0.529653  0.507400  0.666589  0.649590
# 青海省       1.000000  0.977429  0.977404  0.972500  1.000000  0.977927
# 黑龙江省      0.616695  0.573143  0.597034  0.586066  0.722907  0.700841
#
#
# year          2018      2019
# 省份
# 上海市       1.000000  0.994997
# 云南省       0.677801  0.667369
# 内蒙古自治区    0.563905  0.559890
# 北京市       1.000000  1.000000
# 吉林省       0.707725  0.702631
# 四川省       0.731735  0.728581
# 天津市       0.675613  0.675057
# 宁夏回族自治区   0.996855  1.000000
# 安徽省       0.687597  0.690851
# 山东省       0.807028  0.813583
# 山西省       0.716257  0.714779
# 广东省       0.991323  1.000000
# 广西壮族自治区   0.669861  0.657739
# 新疆维吾尔自治区  0.685805  0.631281
# 江苏省       1.000000  0.997894
# 江西省       0.663891  0.648117
# 河北省       0.691145  0.681444
# 河南省       0.703478  0.706125
# 浙江省       0.923886  0.917615
# 海南省       0.862335  0.832827
# 湖北省       0.725418  0.731010
# 湖南省       0.708881  0.712188
# 甘肃省       0.662955  0.657492
# 福建省       0.736326  0.736693
# 贵州省       0.668865  0.647522
# 辽宁省       0.709054  0.712225
# 重庆市       0.680275  0.679629
# 陕西省       0.680112  0.669972
# 青海省       0.977904  0.973236
# 黑龙江省      0.712776  0.707247

# %%
HYPER_CRS3.to_markdown("HYPER_CRS.md")
HYPER_VRS3.to_markdown("HYPER_VRS.md")

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %% [markdown]
# ## DDF

# %%
from deabook import DEA
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_CRS, \
                        OPT_LOCAL

# %%
def DDF_CRS():

    model = DEA.DDF2(data,sent = "K L E=Y",  gy=[0], gx=[1,0,0],rts=RTS_CRS, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_CRS=DDF_CRS()
DDF_CRS
# Out:
# Optimizing locally.
#     optimization_status           rho       tei
# 0                    ok  2.279562e-16  1.000000
# 1                    ok  0.000000e+00  1.000000
# 2                    ok  1.798760e-01  0.820124
# 3                    ok  2.738965e-01  0.726104
# 4                    ok  5.958635e-01  0.404137
# ..                  ...           ...       ...
# 115                  ok  7.578814e-01  0.242119
# 116                  ok  6.036280e-01  0.396372
# 117                  ok  6.421395e-01  0.357861
# 118                  ok  6.228342e-01  0.377166
# 119                  ok  6.304191e-01  0.369581
#
# [120 rows x 3 columns]

# %% [markdown]
# ### DDF的结果和DEA的结果是一样的，这说明两者都对

# %%
def DDF_VRS():

    model = DEA.DDF2(data,sent = "K L E=Y",  gy=[0], gx=[1,0,0],rts=RTS_VRS1, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_VRS=DDF_VRS()
DDF_VRS
# Out:
# Optimizing locally.
#     optimization_status       rho       tei
# 0                    ok  0.000000  1.000000
# 1                    ok  0.000000  1.000000
# 2                    ok  0.000000  1.000000
# 3                    ok  0.144732  0.855268
# 4                    ok  0.510398  0.489602
# ..                  ...       ...       ...
# 115                  ok  0.071876  0.928124
# 116                  ok  0.506330  0.493670
# 117                  ok  0.550551  0.449449
# 118                  ok  0.526035  0.473965
# 119                  ok  0.537811  0.462189
#
# [120 rows x 3 columns]

# %%
DDF_CRS['EI_CRS'] =  DDF_CRS['tei']
DDF_VRS['EI_VRS'] = DDF_VRS['tei']

DDF_CRS = DDF_CRS.drop(columns = ['optimization_status','rho'])
DDF_VRS = DDF_VRS.drop(columns = ['optimization_status','rho'])



DDF_CRS2 = pd.concat([DDF_CRS,yearid],axis=1)
DDF_VRS2 = pd.concat([DDF_VRS,yearid],axis=1)

# %%
DDF_CRS2
# Out:
#           tei    EI_CRS  year    省份
# 0    1.000000  1.000000  2016   上海市
# 1    1.000000  1.000000  2017   上海市
# 2    0.820124  0.820124  2018   上海市
# 3    0.726104  0.726104  2019   上海市
# 4    0.404137  0.404137  2016   云南省
# ..        ...       ...   ...   ...
# 115  0.242119  0.242119  2019   青海省
# 116  0.396372  0.396372  2016  黑龙江省
# 117  0.357861  0.357861  2017  黑龙江省
# 118  0.377166  0.377166  2018  黑龙江省
# 119  0.369581  0.369581  2019  黑龙江省
#
# [120 rows x 4 columns]

# %%
DDF_CRS3 = DDF_CRS2.pivot_table(
    values=['EI_CRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_VRS3 = DDF_VRS2.pivot_table(
    values=['EI_VRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_CRS3.to_markdown("DDF_CRS.md")
DDF_VRS3.to_markdown("DDF_VRS.md")

# %%
SSS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 SSS
#
# NameError: name 'SSS' is not defined

# %% [markdown]
# ## figure

# %%
DDF_VRS3
# Out:
#             EI_VRS
# year          2016      2017      2018      2019
# 省份
# 上海市       1.000000  1.000000  1.000000  0.855268
# 云南省       0.489602  0.425438  0.396031  0.373321
# 内蒙古自治区    0.285970  0.274692  0.156679  0.146878
# 北京市       1.000000  1.000000  1.000000  1.000000
# 吉林省       0.374422  0.341753  0.466090  0.456400
# 四川省       0.384274  0.356937  0.420860  0.413086
# 天津市       0.386314  0.366903  0.404533  0.403225
# 宁夏回族自治区   0.980790  1.000000  0.895675  1.000000
# 安徽省       0.346161  0.314501  0.379610  0.384507
# 山东省       0.489834  0.440159  0.484878  0.483100
# 山西省       0.456794  0.504958  0.473228  0.470169
# 广东省       1.000000  1.000000  0.978424  1.000000
# 广西壮族自治区   0.399730  0.352609  0.377911  0.351811
# 新疆维吾尔自治区  0.493917  0.451226  0.426144  0.308975
# 江苏省       0.687181  0.769586  1.000000  0.959713
# 江西省       0.379191  0.333605  0.367253  0.333609
# 河北省       0.389537  0.355035  0.334416  0.316721
# 河南省       0.362264  0.332420  0.362940  0.368416
# 浙江省       0.601257  0.564425  0.607875  0.590111
# 海南省       1.000000  0.881673  0.446956  0.446437
# 湖北省       0.405794  0.365092  0.412835  0.422469
# 湖南省       0.431308  0.378707  0.413601  0.415482
# 甘肃省       0.473676  0.461604  0.395298  0.382855
# 福建省       0.420024  0.379849  0.441161  0.443156
# 贵州省       0.472139  0.402739  0.393266  0.346942
# 辽宁省       0.355639  0.377676  0.415754  0.422030
# 重庆市       0.390862  0.346966  0.408760  0.406437
# 陕西省       0.373080  0.335785  0.399098  0.377449
# 青海省       1.000000  0.874745  0.923259  0.928124
# 黑龙江省      0.493670  0.449449  0.473965  0.462189

# %%
ddf_mean_year = DDF_VRS3['EI_VRS'].mean()

xtick2 = tuple(ddf_mean_year.index)

# %%
ddf_mean_year.mean()
# Out:
# np.float64(0.5223945230184306)

# %%
ddf_mean_year
# Out:
# year
# 2016    0.544114
# 2017    0.514618
# 2018    0.521883
# 2019    0.508963
# dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib notebook
# plt.figure(figsize=(1,1))
params = {
    'figure.figsize': '8, 4'
}
# plt.rcParams.update(params)
# plt.rc('font',family='Times New Roman')
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'


import numpy as np

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################

n_groups = 4 # 样本的数目（ref，mut1-3）
index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.plot(index, ddf_mean_year,
                color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='DDF_VRS'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )

###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{资本效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap2分年份资本效率-省.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap2分年份资本效率-国.png", dpi=900, bbox_inches = 'tight')
plt.show()
# Out:
# <div id='dc54c518-544a-45b9-a4de-9416dcd7ee17'></div>

# %%
ddf_mean_cou = DDF_VRS3['EI_VRS'].mean(axis=1) .sort_values()

# %%
ddf_mean_cou
# Out:
# 省份
# 内蒙古自治区      0.216055
# 河北省         0.348927
# 江西省         0.353414
# 安徽省         0.356195
# 河南省         0.356510
# 广西壮族自治区     0.370515
# 陕西省         0.371353
# 重庆市         0.388257
# 天津市         0.390244
# 辽宁省         0.392775
# 四川省         0.393789
# 湖北省         0.401548
# 贵州省         0.403771
# 吉林省         0.409666
# 湖南省         0.409774
# 新疆维吾尔自治区    0.420065
# 福建省         0.421047
# 云南省         0.421098
# 甘肃省         0.428358
# 黑龙江省        0.469818
# 山东省         0.474492
# 山西省         0.476287
# 浙江省         0.590917
# 海南省         0.693767
# 江苏省         0.854120
# 青海省         0.931532
# 上海市         0.963817
# 宁夏回族自治区     0.969116
# 广东省         0.994606
# 北京市         1.000000
# dtype: float64

# %%
xtick2 = tuple(ddf_mean_cou.index)
xtick2
# Out:
# ('内蒙古自治区',
#  '河北省',
#  '江西省',
#  '安徽省',
#  '河南省',
#  '广西壮族自治区',
#  '陕西省',
#  '重庆市',
#  '天津市',
#  '辽宁省',
#  '四川省',
#  '湖北省',
#  '贵州省',
#  '吉林省',
#  '湖南省',
#  '新疆维吾尔自治区',
#  '福建省',
#  '云南省',
#  '甘肃省',
#  '黑龙江省',
#  '山东省',
#  '山西省',
#  '浙江省',
#  '海南省',
#  '江苏省',
#  '青海省',
#  '上海市',
#  '宁夏回族自治区',
#  '广东省',
#  '北京市')

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################
if kind=="province":
   n_groups = 30 # 样本的数目（ref，mut1-3）
else:
   n_groups = 33  

index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子

rects2 = ax.bar(index , ddf_mean_cou,
                bar_width/2,
                color='olivedrab',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='DDF_VRS'
              )

###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{资本效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend(loc='upper left')#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap2分省份资本效率.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap2分国家资本效率.png", dpi=900, bbox_inches = 'tight')

plt.show()
# Out:
# <div id='f1eff33a-8531-4d4f-a63b-bc92cbbe8e57'></div>

# %%
if kind=="province":

    DDF_VRS4 = pd.merge(DDF_VRS3['EI_VRS'].reset_index(),region.drop_duplicates(),on=['省份'],how="left")
    DDF_VRS5 = DDF_VRS4.drop(columns=['省份']).groupby('group').mean()
    xtick2 = tuple(DDF_VRS5.loc["W"].index)

# %%
if kind=="province":
  fig, ax = plt.subplots() # 创建图形网格


  ax.spines['top'].set_visible(False) # 使上边框不可见
  ax.spines['right'].set_visible(False)
  # ax2.spines['right'].set_visible(False)

  ################################ 绘图 #################################

  n_groups = 4 # 样本的数目（ref，mut1-3）
  index = np.arange(n_groups) # 转换为列表
  bar_width = 0.5 # 设置柱子的宽度
  # opacity = 0.8 # 设置柱子的透明度
  error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



  # 画第一个样本的柱子
  rects1 = ax.plot(index, DDF_VRS5.loc['E'],
                  color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='东部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  rects2 = ax.plot(index, DDF_VRS5.loc['C'],
                  color='olivedrab',alpha = 0.8,linestyle = "dashed",marker = "^",label='中部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  rects3 = ax.plot(index, DDF_VRS5.loc['W'],
                  color='orange',alpha = 0.8,linestyle = "dashed",marker = "+",label='西部'
              #      error_kw=error_config,
              #   edgecolor = 'white'
                )
  ###########################################333

  # ax.set_xlabel('Hours in 4 ℃')
  ax.set_ylabel( r'$\mathregular{资本效率}$')
  #  r'$Difficulty of reducing emissions \gamma$' 
  # ax.set_title('Creat by python')
  ax.set_xticks(index )
  ax.set_xticklabels(xtick2)
  # ax2.set_xlabel('Relative gene expression')
  # ax.spines["bottom"].set_position(("data",0))
  plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

  plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
  # ax.legend(frameon=False,loc='best',ncol = 1)
  plt.savefig("chap2分年份地区资本效率-省.png", dpi=900, bbox_inches = 'tight')

  plt.show()
# Out:
# <div id='1edd1010-21f2-421d-9fe6-9cfd5dfa9e73'></div>
